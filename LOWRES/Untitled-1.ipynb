# %%
from script_general import script_general
import random

# %%
#seed = random.randint(0, 1e6)             # Semilla para generar una instancia aleatoria fija.

# semillas malas (gc -> generación de columnas)
# 585 con 10 viajes
# 388
# viajes = 3 , w = 60

K = 0.1                                 # Constante para transformar el consumo de combustible en tiempo recargando.

#num_travels = 10                         # Número de viajes.
num_depots = 3                          # Número de depósitos.
num_charge_stations = 5                 # Número de estaciones de carga.
num_passenger_stations = 10             # Número de estaciones de pasajeros.

w = 100.0                               # Capacidad de combustible de cada vehículo.

speed_bus = 3.0                         # Velocidad del bus (km/h).
fuel_per_distance = 2.0                 # Combustibple requerido por distancia ej. litros de gasolina/km.
cost_per_distance = 1.0                 # Costo por distancia (sucres/km).

h_s = 6.0                               # Hora de inicio de la jornada.
h_f = 20.0                              # Hora de final de la jornada.

time_divisions = 50                     # Número de divisiones temporales para discretización.

v_max = 100                             # Capacidad máxima de un depósito dado (más adelante, la capacidad se genera aleatoriamente entre v_min y v_max).
v_min = 10                              # capacidad mínima de un depósito dato


size_square = 10                        # Lado de una ciudad cuadrada (km).


# Se considera la capacidad limitada de las estaciones de carga.
max_capacity_charge_station = 200         # Capacidad máxima de una estacion de carga por unidad de tiempo.
                                        # (mas adelante, la capacidad se genera aleatoriamente entre min_capacity_charge_station y max_capacity_charge_station).

min_capacity_charge_station = 30       # Capacidad mínima de una estación de carga en un tiempo dado

# %%
#viajes_testeados = [380, 385, 390, 395, 400, 405, 410]
viajes_testeados = [300]

# %%
for _ in range(1):
    seed = 728216#random.randint(0, 1e6) # con la misma semilla
    print(seed)
    for i_viaje in viajes_testeados:
        num_travels = i_viaje
        print(f'------------ {num_travels} --- {seed} ------------')
        script_general(seed,K,num_travels,num_depots,num_charge_stations,num_passenger_stations,w,speed_bus,fuel_per_distance,cost_per_distance,h_s,h_f,time_divisions,v_max,v_min,size_square,max_capacity_charge_station,min_capacity_charge_station )
        print("-"*10)
# Out:
# 728216
# ------------ 300 --- 728216 ------------
# time discretization completed in 2.384185791015625e-05
# generate data completed in 0.0016231536865234375
# create nodes completed in 0.4606819152832031
# compatibilities completed in 31.734889030456543
# create archs completed in 2232.376513004303
# cost and fuel completed in 0.0007190704345703125
# M1 en 0.31587791442871094
# M2 en 0.0031011104583740234
# Hk en 2.002716064453125e-05
# Ak en 0.0006568431854248047
# Hk_complete en 0.3548920154571533
# el resto... en 4.774806976318359
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-11
# todas las restricciones menos la septima en 102.49602818489075
# la septima en 18.401851892471313
# Set parameter LogFile to value "logs_new/salida_modelo_arcos_300_728216.log"
# Set parameter TimeLimit to value 7200
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3291383 rows, 2365104 columns and 14452456 nonzeros
# Model fingerprint: 0x88c2f0a8
# Variable types: 76053 continuous, 2289051 integer (2289051 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 2e+07]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 2e+07]
# Presolve removed 336285 rows and 70338 columns (presolve time = 5s) ...
# Presolve removed 397102 rows and 88791 columns (presolve time = 10s) ...
# Presolve removed 1754525 rows and 98828 columns (presolve time = 15s) ...
# Presolve removed 2007493 rows and 99804 columns (presolve time = 20s) ...
# Presolve removed 2035568 rows and 100532 columns (presolve time = 25s) ...
# Presolve removed 2037619 rows and 100532 columns (presolve time = 30s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 35s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 40s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 45s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 50s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 55s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 60s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 65s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 70s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 75s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 80s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 86s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 91s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 95s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 100s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 105s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 110s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 115s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 120s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 125s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 130s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 135s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 140s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 145s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 150s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 155s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 160s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 165s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 170s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 175s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 180s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 185s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 190s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 195s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 200s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 205s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 210s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 215s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 220s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 225s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 230s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 235s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 240s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 245s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 250s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 255s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 260s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 265s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 270s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 275s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 280s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 285s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 290s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 295s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 300s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 305s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 310s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 315s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 320s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 325s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 330s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 335s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 340s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 345s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 350s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 355s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 360s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 365s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 370s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 375s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 380s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 385s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 390s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 395s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 400s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 405s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 410s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 415s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 420s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 425s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 430s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 435s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 440s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 445s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 450s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 455s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 460s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 465s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 470s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 475s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 480s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 485s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 490s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 495s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 500s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 505s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 510s) ...
# Presolve removed 2038507 rows and 101710 columns (presolve time = 515s) ...
# Presolve removed 2038507 rows and 877700 columns (presolve time = 521s) ...
# Presolve removed 2573093 rows and 897699 columns (presolve time = 525s) ...
# Presolve removed 2606143 rows and 898486 columns (presolve time = 530s) ...
# Presolve removed 2606628 rows and 899314 columns
# Presolve time: 534.31s
# Presolved: 684755 rows, 1465790 columns, 5205897 nonzeros
# Variable types: 2 continuous, 1465788 integer (1455687 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 5s
# Elapsed ordering time = 10s
# Elapsed ordering time = 15s
# Elapsed ordering time = 20s
# Elapsed ordering time = 25s
# Elapsed ordering time = 30s
# Elapsed ordering time = 35s
# Elapsed ordering time = 40s
# Ordering time: 42.53s
#
# Barrier statistics:
#  Dense cols : 149
#  AA' NZ     : 2.747e+07
#  Factor NZ  : 1.675e+08 (roughly 2.0 GB of memory)
#  Factor Ops : 7.618e+10 (roughly 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18268891e+09 -2.34106614e+09  2.87e+07 6.00e+00  5.38e+04   630s
#    1   1.83883070e+09 -2.33811096e+09  2.42e+07 1.27e+01  4.46e+04   640s
#    2   1.47100179e+09 -2.33751127e+09  1.94e+07 7.05e+00  3.48e+04   657s
#    3   1.09134459e+09 -2.30838632e+09  1.44e+07 1.49e+00  2.53e+04   672s
#    4   7.09400946e+08 -2.24726259e+09  9.36e+06 5.25e-02  1.64e+04   690s
#    5   2.25211238e+08 -2.08508672e+09  2.95e+06 1.72e-08  5.36e+03   718s
#    6   5.12447714e+07 -1.78849272e+09  6.56e+05 3.88e-08  1.47e+03   740s
#    7   3.30236925e+07 -1.16667851e+09  4.17e+05 2.87e-08  8.25e+02   758s
#    8   2.67230214e+07 -8.72882364e+08  3.37e+05 2.79e-09  6.13e+02   771s
#    9   2.08919955e+07 -5.80575155e+08  2.63e+05 6.50e-09  4.41e+02   782s
#   10   1.35119418e+07 -3.51562600e+08  1.70e+05 1.92e-09  2.80e+02   792s
#   11   9.67099026e+06 -2.42508805e+08  1.22e+05 1.83e-09  1.97e+02   804s
#   12   4.77268505e+06 -1.45051385e+08  5.98e+04 1.91e-09  1.04e+02   817s
#   13   2.77177335e+06 -7.75682260e+07  3.46e+04 5.41e-10  5.85e+01   833s
#   14   1.55985467e+06 -4.48889647e+07  1.94e+04 1.23e-09  3.30e+01   851s
#   15   1.11651478e+06 -2.87575380e+07  1.39e+04 8.14e-10  2.25e+01   874s
#   16   6.63515058e+05 -1.33686195e+07  8.21e+03 2.99e-10  1.21e+01   890s
#   17   4.42860829e+05 -8.65509145e+06  5.47e+03 2.52e-10  7.96e+00   901s
#
# Barrier performed 17 iterations in 901.47 seconds (773.15 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 1.96s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    22623    7.0700000e+02   0.000000e+00   0.000000e+00    903s
# Extra simplex iterations after uncrush: 1
#
# Root relaxation: objective 7.070000e+02, 22623 iterations, 334.05 seconds (93.19 work units)
# Total elapsed time = 932.79s (DegenMoves)
# Total elapsed time = 955.18s (DegenMoves)
# Total elapsed time = 976.16s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  707.00000    0   98          -  707.00000      -     -  986s
#      0     0  707.00000    0  291          -  707.00000      -     - 1027s
#      0     0  707.00000    0  524          -  707.00000      -     - 1135s
#      0     0  713.00000    0   23          -  713.00000      -     - 1968s
# H    0     0                     813.0000000  713.00000  12.3%     - 1978s
# H    0     0                     765.0000000  713.00000  6.80%     - 1981s
#      0     0  713.00000    0  134  765.00000  713.00000  6.80%     - 1998s
# H    0     0                     713.0000000  713.00000  0.00%     - 2010s
#      0     0  713.00000    0  134  713.00000  713.00000  0.00%     - 2010s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 6
#   Clique: 5
#   MIR: 9
#   StrongCG: 3
#   Relax-and-lift: 20
#
# Explored 1 nodes (258989 simplex iterations) in 2010.91 seconds (1903.97 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 713 765 813
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.130000000000e+02, best bound 7.130000000000e+02, gap 0.0000%
# 713.0	2133.7855191230774
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 num_travels = i_viaje
#       6 print(f'------------ {num_travels} --- {seed} ------------')
# ----> 7 script_general(seed,K,num_travels,num_depots,num_charge_stations,num_passenger_stations,w,speed_bus,fuel_per_distance,cost_per_distance,h_s,h_f,time_divisions,v_max,v_min,size_square,max_capacity_charge_station,min_capacity_charge_station )
#       8 print("-"*10)
#
# File ~/codigo_modular_optimizade/script_general.py:254, in script_general(seed, K, num_travels, num_depots, num_charge_stations, num_passenger_stations, w, speed_bus, fuel_per_distance, cost_per_distance, h_s, h_f, time_divisions, v_max, v_min, size_square, max_capacity_charge_station, min_capacity_charge_station)
#     248 inicio1 = time.time()
#     250 num_max_it          = 1900        #número de máximas iteraciones para el modelo (para no saturar gurobi ni el PC).
#     252 (new_paths,
#     253 dic_cost_path,
# --> 254 x_op,
#     255 z_op)              = initial_model(seed,list_comp_FT,K, Travels, Depots, Stations_chrg_time, Stations_chrg_time_dic, Stations_chrg_time_dic_inv, D_v, rs_kt, h, Stations_chrg, dic_comp, cost, list_time, w, fuel, h_inv, dic_comp_F, T_ab, num_max_it, delta, time_window, t, time_dic, delta_mas_i, delta_mas_k, delta_mas_h)
#     257 fin1 = time.time()
#     258 tiempo_modelo_caminos = fin1 - inicio1
#
# File ~/codigo_modular_optimizade/initial_model.py:171, in initial_model(seed, list_comp_FT, K, Travels, Depots, Stations_chrg_time, Stations_chrg_time_dic, Stations_chrg_time_dic_inv, D_v, rs_kt, h, Stations_chrg, dic_comp, cost, list_time, w, fuel, h_inv, dic_comp_F, T_ab, num_max_it, delta, time_window, t, time_dic, delta_mas_i, delta_mas_k, delta_mas_h)
#     167     archivo.write(f'z_heuristica\t{z_heuristic}')
#     169 #model.write(f"modelo_lp.lp")
# --> 171 if model.status == gp.GRB.OPTIMAL:
#     172     # Obtener el valor óptimo de la función objetivo
#     173     optimal_value = model.objVal
#     174     #print('Valor óptimo de la función objetivo:', optimal_value)
#
# UnboundLocalError: local variable 'optimal_value' referenced before assignment
